# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # plot psf versus measured speckle sizes

# %%
measured_size_NA=[457,168,137,105]
psf_NA=[396,222.75,162,148.5]
n=['0.45 N.A.','0.8 N.A.', '1.1 N.A.', '1.2 N.A.']
fig, ax = plt.subplots()
ax.scatter(psf_NA, measured_size_NA,c='k')

for i, txt in enumerate(n):
    ax.annotate(txt, (psf_NA[i]-10, measured_size_NA[i]-30),xycoords='data')

plt.tick_params(bottom=True, top=True, left=True, right=True,direction='in')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0,550)
plt.xlabel('Point Spread Function (nm)',size=18)
plt.ylabel('Speckle Size (nm)',size=18)
plt.legend(fontsize=18)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
measured_size_NA=[411,457,477,491]
psf_NA=[351,396,432,540]
n=['0.26 A.U.','0.52 A.U.', '0.78 A.U.', '1 A.U.']
fig, ax = plt.subplots()
ax.scatter(psf_NA, measured_size_NA,c='k')

for i, txt in enumerate(n):
    ax.annotate(txt, (psf_NA[i]-6, measured_size_NA[i]+5),xycoords='data')

plt.tick_params(bottom=True, top=True, left=True, right=True,direction='in')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(300,600)
plt.ylim(350,600)
plt.xlabel('Point Spread Function (nm)',size=18)
plt.ylabel('Speckle Size (nm)',size=18)
plt.legend(fontsize=18)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
au=[0.26, 0.52, 0.78, 1]
contrast=[0.618226049,0.495740801,0.413857826,0.35796003]
plt.plot(au,contrast,'k')
plt.tick_params(bottom=True, top=True, left=True, right=True,direction='in')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0,1)
plt.xlabel('Airy Unit (A.U.)',size=18)
plt.ylabel('C',size=18)
# Out:
# Text(0, 0.5, 'C')
