# %%
import pickle

# Define the path to the .p file
pickle_file_path = '/Volumes/wwyyrx/Wenyun/Silk_speckle/20230524/20min_age_1_corrmaps.p'

# Open the .p file in binary read mode
with open(pickle_file_path, 'rb') as file:
    # Load the data from the file
    data = pickle.load(file)

# Now, 'data' holds the Python object that was stored in the file

# %%
data.shape
# Out:
# (1, 3, 128, 128)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is a DataFrame or a 2D NumPy array
# If 'data' is not defined, you can create a sample DataFrame to demonstrate
# import pandas as pd
# import numpy as np
# data = pd.DataFrame(np.random.rand(10, 12))

# Create the heatmap
sns.heatmap(data[0,1])

# Display the plot
plt.show()

# %%
import pickle

# Define the path to the .p file
pickle_file_path = '/Volumes/wwyyrx/Wenyun/Silk_speckle/20230524/30min_age_2_corrmaps.p'

# Open the .p file in binary read mode
with open(pickle_file_path, 'rb') as file:
    # Load the data from the file
    data = pickle.load(file)

# Now, 'data' holds the Python object that was stored in the file

# %%
data.shape
# Out:
# (1, 3, 128, 128)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is a DataFrame or a 2D NumPy array
# If 'data' is not defined, you can create a sample DataFrame to demonstrate
# import pandas as pd
# import numpy as np
# data = pd.DataFrame(np.random.rand(10, 12))

# Create the heatmap
sns.heatmap(data[0,1])

# Display the plot
plt.show()
